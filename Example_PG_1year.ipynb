# %%
import xarray as xr
import sys
import numpy as np

#from pyTEF import *

indir = '/fast/lorenz/pyTEF_data/'

data = xr.open_mfdataset(indir+'SoH_2_2011_01.nc',combine='by_coords',concat_dim='time').load()

# %%
(-data.velx3d*data.hn*data.dyc).shape
# Out:
# (744, 40, 51, 1)

# %%
q, Q, sq, sQ = sort_1dim(data.salt,-data.velx3d*data.hn*data.dyc,keep_time=True,N=1024,salinity_array='auto')
# Out:
# (744, 40, 51, 1) (744, 40, 51, 1)
# input is good
# 744
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-0f7c273054a9> in <module>
# ----> 1 q, Q, sq, sQ = sort_1dim(data.salt,-data.velx3d*data.hn*data.dyc,keep_time=True,N=1024,salinity_array='auto')
#
# /silor/boergel/projects/pyTEF/pyTEF.py in sort_1dim(salt, flux, keep_time, N, salinity_array, time_array)
#     410         Qv = np.zeros((tmax,np.shape(qv)[0]+1))
#     411         for i in range(0,int(qv.shape[1])): #calculate Q(s) and Q_s(s)
# --> 412             Qv[:,i]=np.sum(qv[:,i:]*DeltaS)
#     413
#     414     #create a xarray Dataset for the results
#
# IndexError: index 745 is out of bounds for axis 1 with size 745

# %%
import matplotlib.pyplot as plt
plt.pcolormesh(data.time,sq,q.transpose(),vmin=-400000,vmax=400000,cmap='coolwarm')
plt.colorbar()

# %%
#q_mean=q.mean(axis=0)
#plt.plot(q_mean,sq)

# %%
#data.time.values

# %%
data_tef_vol=sort_1dim_xarray(data,'salt',['velx3d','hn','dyc'])
#data_tef_salt=pyTEF.sort_1dim_xarray(data,'salt',['salt','velx3d','hn','dyc'])
# Out:
# 1
# 2
# (744, 40, 51, 1) (744, 40, 51, 1)
# input is good
# 744

# %%
data_tef_vol.q.plot(vmin=-1e06,vmax=1e06)

# %%
data_tef_vol.q.mean(axis=0).plot()

# %%
bulk_values_vol=calc_bulk_values(data_tef_vol)
# Out:
# [  0 510 916] ['min' 'max' 'min']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-c354445bdc79> in <module>
# ----> 1 bulk_values_vol=calc_bulk_values(data_tef_vol)
#
# /silor/boergel/projects/pyTEF/pyTEF.py in calc_bulk_values(data, coord, Q, min_trans)
#      47             while i < len(ind)-1:
#      48                 Q_i=-(Qv[ind[i+1]]-Qv[ind[i]])
# ---> 49                 if Q_i<0:
#      50                     Q_out_m.append(Q_i)
#      51                 elif Q_i > 0:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#data_tef_2d=pyTEF.sort_2dim_xarray(data,dim=['temp','salt'],var=['velx3d','hn','dyc'])

# %%
#q_mean=data_tef_2d.q.mean(axis=0)

# %%
#q_mean.plot(vmin=-2e05,vmax=2e05,cmap='seismic')
